# %% [markdown]
# # EDA

# %% [markdown]
# ## Importaciones

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import math
import seaborn as sns 

ve_us = pd.read_csv("https://raw.githubusercontent.com/Arentilien/sprint7/refs/heads/main/vehicles_us.csv")

# %% [markdown]
# ## Analisis general

# %%
ve_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# ## Preparacion de Datos

# %%
ve_us['model_year'] = ve_us['model_year'].fillna(0) #se tienen que sustituir por 0 los valores nulos
ve_us['model_year'] = ve_us['model_year'].astype(int) #Se convierten a enteros, el año no puede ser decimal
ve_us['model_year'] = ve_us['model_year'].astype(str) #No se van a hacer operaciones con el año, por lo que se convierte a string
ve_us['model_year'] = ve_us['model_year'].replace('0', 'NaN') #Se tiene que saber que el año no puede ser 0


ve_us['cylinders'] = ve_us['cylinders'].fillna(0) #Se tiene que convertir el cilindraje en 0 los valores nulos
ve_us['cylinders'] = ve_us['cylinders'].astype(int) #Se convierten a enteros, el cilindraje no puede ser decimal
ve_us['cylinders'] = ve_us['cylinders'].astype(str) #No se van a hacer operaciones con el cilindraje, por lo que se convierte a string
ve_us['cylinders'] = ve_us['cylinders'].replace('0', 'NaN') #No se puede asumir el cilindraje con la media, se tomara como NaN


ve_us['is_4wd'] = ve_us['is_4wd'].fillna(0) #Se tienen que sustituir por 0 los valores nulos
ve_us['is_4wd'] = ve_us['is_4wd'].astype(int) #Se convierten a enteros, el 4wd no puede ser decimal
ve_us['is_4wd'] = ve_us['is_4wd'].astype(str) #No se van a hacer operaciones con el 4wd, por lo que se convierte a string


ve_us['paint_color'] = ve_us['paint_color'].fillna('NaN') #Para no perder datos los valores nulos son Nan

ve_us['odometer'] = ve_us['odometer'].fillna(-1) #Damos un valor a los nulos para trabajar
ve_us['odometer'] = ve_us['odometer'].astype(int) #convertimos a enteros, no se puede ser flotante
ve_us['odometer'] = ve_us['odometer'].replace(-1, 'NaN') #Sustituimos el -1 por NaN, y los datos conservan estructura





ve_us.head(5)
# Out:
#    price model_year           model  condition cylinders fuel odometer  \
# 0   9400       2011          bmw x5       good         6  gas   145000
# 1  25500        NaN      ford f-150       good         6  gas    88705
# 2   5500       2013  hyundai sonata   like new         4  gas   110000
# 3   1500       2003      ford f-150       fair         8  gas      NaN
# 4  14900       2017    chrysler 200  excellent         4  gas    80903
#
#   transmission    type paint_color is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN      1  2018-06-23           19
# 1    automatic  pickup       white      1  2018-10-19           50
# 2    automatic   sedan         red      0  2019-02-07           79
# 3    automatic  pickup         NaN      0  2019-03-22            9
# 4    automatic   sedan       black      0  2019-04-02           28

# %% [markdown]
# Se hicieron algunos ajustes en los datos para que funcionararn de manera correcta:
#
# 1.- Los valores de años, cylindros, y pintura se les colocaron correctamente los calores nulos, para que no se perdiera esa información, ya que de todas formas tenemos que estos datos son str y no datos con los que haremos operaciones entre ellos.
#
# 2.- En el odometro no pude eliminar los datos nulos, ya que casi un quinto de los datos estaban ausentes. El primer intento fue colocarles el valor de la media, pero deformaba los datos incoherentemente, posteriomente quise colocarles el valor cero, y se deformaba pero el valor cero existe, entonces se sesgaban los datos, por lo que la mejor decision fue dejarlo como valor nulo y la grafica funciono correctamente

# %%
fig = px.histogram(ve_us, x='odometer', y='price')
fig.show()

# %%
fig = px.scatter(ve_us, x='days_listed', y='price')
fig.show()

# %%
fig = px.histogram(ve_us, x='price')
fig.show()

# %%
#prueba con los datos segun fecha de los coches

fig = px.scatter(ve_us, x='days_listed', y='price', color='paint_color')
fig.show()

# %% [markdown]
# ## Analisis General de datos
